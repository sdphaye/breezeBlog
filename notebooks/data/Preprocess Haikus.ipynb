# %%
import json
from pathlib import Path
import re
# !pip install inflect
import inflect
import numpy as np
import pandas as pd
# Out:
# Collecting inflect
#   Downloading inflect-5.3.0-py3-none-any.whl (32 kB)
# Installing collected packages: inflect
# Successfully installed inflect-5.3.0

# %%
root_path = Path('../..')
input_path = root_path / 'input' 
dictionary_path = input_path / 'dictionaries'
poem_path = input_path / 'poems'
raw_path = poem_path / 'raw'

all_haikus = []

# %% [markdown]
# # Load Tempslibres Poems
#
# Load haikus from tempslibres, which were downloaded to `tempslibres.csv` using `Download Haikus From Tempslibres.ipynb`

# %%
# Load the file
df = pd.read_csv(str(raw_path / 'tempslibres.csv'), encoding='latin1')
df = df[df['lang'] == 'en'].copy()

# Only keep the first three lines of english haikus 
df = df[~pd.isnull(df['0']) & ~pd.isnull(df['1']) & ~pd.isnull(df['2'])].copy()
df = df[['0', '1', '2']]
df.columns = [0, 1, 2]

df['source'] = 'tempslibres'
all_haikus.append(df)
df.head()
# Out:
#                    0                     1                  2       source
# 3    Memorial Day --     a shadow for each        white cross  tempslibres
# 4      spring rain -  as the doctor speaks  i think of lilacs  tempslibres
# 5  spring moonset --       a rice ball for          breakfast  tempslibres
# 6    sunny afternoon    an old man lingers   near the mailbox  tempslibres
# 7      cinco de mayo           horses roll    in the shallows  tempslibres

# %%
df.columns
# Out:
# Index([0, 1, 2, 'source'], dtype='object')

# %% [markdown]
# # Load img2poem
#
# The data from the paper [Beyond Narrative Description: Generating Poetry from Images by Multi-Adversarial Training](https://arxiv.org/abs/1804.08473).
#
# From: https://github.com/bei21/img2poem
#
# It contains many different types of poems, so only keep three line poems.

# %%
# Read the JSON file
with (raw_path / 'unim_poem.json').open('r') as f:
    j = json.load(f)
    
# keep only the three line poems
df = pd.DataFrame({
    'haiku': [i['poem'] for i in j if len(i['poem'].split('\n')) == 3]
})

# Split them into lines
df = df['haiku'].str.split('\n', expand=True)

df['source'] = 'img2poems'
all_haikus.append(df)
df.head()
# Out:
#                                                 0  \
# 0         jesus smiles grabs his guitar and plays
# 1             after a flying ovation she realizes
# 2         you do a lot more talking in your sleep
# 3  look back: you see the path we chose was steep
# 4   there was a time when talk of love came cheap
#
#                                                1  \
# 0    a couple of familiar riffs crooning take it
# 1       she is not with the kozmic blues band or
# 2     than you used to do now you're growing old
# 3  and needed all our strength  but we were bold
# 4    and what was bought was what the other sold
#
#                                                 2     source
# 0  take another little piece of my heart now baby  img2poems
# 1             big brother and the holding company  img2poems
# 2           i wonder what there is for me to keep  img2poems
# 3       it took our breath and left us only sleep  img2poems
# 4       there was so much we didn't think to keep  img2poems

# %% [markdown]
# # PoetRNN
#
# Training data from [Sam Ballas's PoetRNN](https://github.com/sballas8/PoetRNN)

# %%
# Read the CSV and split the haikus into lines
df = pd.read_csv(str(raw_path / 'sballas8.csv'), names=['haiku'])
df = df['haiku'].str.split('\n', expand=True)

# Drop ones without at least three lines
df = df.dropna(subset=[0,1,2])

# Keep only the ones with exactly three lines
df = df[(((df[3] == '') | pd.isnull(df[3])) & pd.isnull(df[[4, 5, 6, 7, 8]]).all(axis=1))]


df = df[[0, 1, 2]]
df['source'] = 'sballas'
all_haikus.append(df)
df.head()
# Out:
#                     0                      1                     2   source
# 0     rectory roofers          their ladders      take them higher  sballas
# 1        summer cabin               the ants         do the dishes  sballas
# 2  lagoon at sunrise?             the shadow    chases its pelican  sballas
# 3        barren trees  even the tiniest twig  embraced by the mist  sballas
# 4     windfall apples             bees tango            to a waltz  sballas

# %% [markdown]
# # Haikuzao
#
# https://github.com/herval/creative_machines/tree/master/haikuzao

# %%
with (raw_path / 'haikuzao.txt').open('r') as f:
    text = f.read()
    
df = pd.DataFrame({
    'haiku': [i for i in text.split('\n\n') if len(i.split('\n')) == 3]
})

# Split them into lines
df = df['haiku'].str.split('\n', expand=True)

df['source'] = 'haikuzao'
all_haikus.append(df)
df.head()
# Out:
#                      0                              1  \
# 0     a skein of birds          twines across the sky
# 1   dawn chorus begins                    I reach for
# 2  en haut des cuisses     dans l'espace sous le slip
# 3       new March snow  the grouse with a missing toe
# 4     Remembrance Day-               even the traffic
#
#                               2    source
# 0  the northbound train departs  haikuzao
# 1             the snooze button  haikuzao
# 2             un morceau de mer  haikuzao
# 3                  still around  haikuzao
# 4          pauses for 2 minutes  haikuzao

# %% [markdown]
# # Gutenberg
#
# Loads the data downloaded by `Gutenberg.ipynb`.

# %%
df = pd.read_csv(raw_path / 'gutenberg.csv')
df = df['haiku'].str.split('\n', expand=True)
df['source'] = 'gutenberg'
all_haikus.append(df)
df.head()
# Out:
#                            0  \
# 0    Force and yielding meet
# 1  Shafts of broken sunlight
# 2         The boat drifts to
# 3       She is an iris, Dark
# 4                  She waves
#
#                                                   1  \
# 0                               together: An attack
# 1                           dissolving Convolutions
# 2                            rest Under the outward
# 3  purple, pale rose, Under the gnarled boughs That
# 4                      delicately With the movement
#
#                                2     source
# 0              is half repulsed.  gutenberg
# 1               of torpid cloud.  gutenberg
# 2             spraying branches.  gutenberg
# 3  shatter their stars of bloom.  gutenberg
# 4                   of the tree.  gutenberg

# %% [markdown]
# # Twaiku
#
# Haikus from the [Twaiku Twitter](https://twitter.com/TwaikuGC) bot which finds haikus on Twitter and scraped using Brendan Brown's [Twitter scraper](https://github.com/bpb27/twitter_scraping).

# %%
df = pd.read_csv(raw_path / 'twaikugc.csv')
df = df[df['id_str'] >= 941376356746702848] # After the account was out of testing

df = df['text'].str.split(r'\n+', expand=True)
df = df.drop(3, axis=1)

df[0] = df[0].str.strip().str.strip('"')
df[2] = df[2].str.strip().str.strip('"')

df['source'] = 'twaiku'

all_haikus.append(df)
df.head()
# Out:
#                      0                               1  \
# 0      Has anyone made        a joke about Kane trying
# 1  Why do dentists try   to talk to you when they have
# 2    Sorry Blazers but      the Pelicans just want the
# 3      U gonna see one          of these for every hot
# 4   Tom Brady has more     super bowl wins than career
#
#                            2  source
# 0      to claim the goal yet  twaiku
# 1  their hands in your mouth  twaiku
# 2      ball more than you do  twaiku
# 3          lady on earth now  twaiku
# 4        losses to the bills  twaiku

# %%
all_haikus = pd.concat(all_haikus, sort=False)

# Drop duplicates because there are some poems in multiple sources
all_haikus['hash'] = (all_haikus[0] + all_haikus[1] + all_haikus[2]).str.replace(r'[^A-Za-z]', '').str.upper()
all_haikus = all_haikus.drop_duplicates(subset=['hash'])

all_haikus
# Out:
#                          0                                 1  \
# 3          Memorial Day --                 a shadow for each
# 4            spring rain -              as the doctor speaks
# 5        spring moonset --                   a rice ball for
# 6          sunny afternoon                an old man lingers
# 7            cinco de mayo                       horses roll
# ...                    ...                               ...
# 118025  I'm not asking did            you say it nor clarify
# 118026     You are truly a               moron or a liar I'm
# 118027  Ain't no selfie on   this earth that's gonna make me
# 118028    is doing a great          job turning Independents
# 118029    Wanted to send a         quick follow up on if the
#
#                               2       source  \
# 3                   white cross  tempslibres
# 4             i think of lilacs  tempslibres
# 5                     breakfast  tempslibres
# 6              near the mailbox  tempslibres
# 7               in the shallows  tempslibres
# ...                         ...          ...
# 118025    what you said neither       twaiku
# 118026   inclined to think both       twaiku
# 118027         like Theresa May       twaiku
# 118028           into Democrats       twaiku
# 118029  blood is loud Talk soon       twaiku
#
#                                                      hash
# 3                     MEMORIALDAYASHADOWFOREACHWHITECROSS
# 4               SPRINGRAINASTHEDOCTORSPEAKSITHINKOFLILACS
# 5                      SPRINGMOONSETARICEBALLFORBREAKFAST
# 6             SUNNYAFTERNOONANOLDMANLINGERSNEARTHEMAILBOX
# 7                      CINCODEMAYOHORSESROLLINTHESHALLOWS
# ...                                                   ...
# 118025  IMNOTASKINGDIDYOUSAYITNORCLARIFYWHATYOUSAIDNEI...
# 118026      YOUARETRULYAMORONORALIARIMINCLINEDTOTHINKBOTH
# 118027  AINTNOSELFIEONTHISEARTHTHATSGONNAMAKEMELIKETHE...
# 118028   ISDOINGAGREATJOBTURNINGINDEPENDENTSINTODEMOCRATS
# 118029  WANTEDTOSENDAQUICKFOLLOWUPONIFTHEBLOODISLOUDTA...
#
# [145033 rows x 5 columns]

# %% [markdown]
# # Get Syllable Count For Each Row

# %%
# Load Phonemes

# Standard Dict
WORDS = {}
with (dictionary_path / 'cmudict.dict.txt').open('r') as f:
    for line in f.readlines():
        word, phonemes = line.strip().split(' ', 1)
        word = re.match(r'([^\(\)]*)(\(\d\))*', word).groups()[0]
        phonemes = phonemes.split(' ')
        syllables = sum([re.match(r'.*\d', p) is not None for p in phonemes])
        #print(word, phonemes, syllables)
        if word not in WORDS:
            WORDS[word] = []
        WORDS[word].append({
            'phonemes': phonemes,
            'syllables': syllables
        })
        
# Load custom phonemes
CUSTOM_WORDS = {}
vowels = ['AA', 'AE', 'AH', 'AO', 'AW', 'AX', 'AXR', 'AY', 'EH', 'ER', 'EY', 'IH', 'IX', 'IY', 'OW', 'OY', 'UH', 'UW', 'UX']
with (dictionary_path / 'custom.dict.txt').open('r') as f:
    for line in f.readlines():
        try:
            word, phonemes = line.strip().split('\t', 1)
        except:
            print(line)
            continue
        word = re.match(r'([^\(\)]*)(\(\d\))*', word).groups()[0].lower()
        phonemes = phonemes.split(' ')
        syllables = sum([(p in vowels) for p in phonemes])
        
        if word not in CUSTOM_WORDS:
            CUSTOM_WORDS[word] = []
        CUSTOM_WORDS[word].append({
            'phonemes': phonemes,
            'syllables': syllables
        })
# Out:
# Ã

# %%
inflect_engine = inflect.engine()

# Dictionary of words not found, must go get the phonemes
# http://www.speech.cs.cmu.edu/tools/lextool.html
NOT_FOUND = set()

def get_words(line):
    """
    Get a list of the words in a line
    """
    line = line.lower()
    # Replace numeric words with the words written out
    ws = []
    for word in line.split(' '):
        if re.search(r'\d', word):
            x = inflect_engine.number_to_words(word).replace('-', ' ')
            ws = ws + x.split(' ')
        else:
            ws.append(word)

    line = ' '.join(ws)

    words = []
    for word in line.split(' '):
        word = re.match(r'[\'"]*([\w\']*)[\'"]*(.*)', word).groups()[0]
        word = word.replace('_', '')
        words.append(word)
        
    return words

def count_non_standard_words(line):
    """
    Count the number of words on the line that don't appear in the default CMU Dictionary.
    """
    count = 0
    for word in get_words(line):
        if word and (word not in WORDS):
            count += 1
    return count

def get_syllable_count(line):
    """
    Get the possible syllable counts for the line
    """
    counts = [0]
    return_none = False
    for word in get_words(line):
        try:
            if word:
                if (word not in WORDS) and (word not in CUSTOM_WORDS):
                    word = word.strip('\'')
                    
                if word in WORDS:
                    syllables = set(p['syllables'] for p in WORDS[word])
                else:
                    syllables = set(p['syllables'] for p in CUSTOM_WORDS[word])
                #print(syllables)
                new_counts = []
                for c in counts:
                    for s in syllables:
                        new_counts.append(c+s)

                counts = new_counts
        except:
            NOT_FOUND.add(word)
            return_none = True

    if return_none:
        return None
    
    return ','.join([str(i) for i in set(counts)])

# %%
# Remove haikus with lots of unknown words
# Likely either non-english or just lots of typos
all_haikus['unknown_word_count'] = np.sum([all_haikus[i].apply(count_non_standard_words) for i in range(3)], axis=0)
all_haikus = all_haikus[all_haikus['unknown_word_count'] < 3].copy()

for i in range(3):
    all_haikus['%s_syllables' % i] = all_haikus[i].apply(get_syllable_count)
    
print("Unknown Words: ", len(NOT_FOUND))

with open('unrecognized_words.txt', 'w') as f:
    for w in NOT_FOUND:
        f.write(w)
        f.write('\n')

all_haikus
# Out:
# Unknown Words:  0
#                          0                                 1  \
# 3          Memorial Day --                 a shadow for each
# 4            spring rain -              as the doctor speaks
# 5        spring moonset --                   a rice ball for
# 6          sunny afternoon                an old man lingers
# 7            cinco de mayo                       horses roll
# ...                    ...                               ...
# 118025  I'm not asking did            you say it nor clarify
# 118026     You are truly a               moron or a liar I'm
# 118027  Ain't no selfie on   this earth that's gonna make me
# 118028    is doing a great          job turning Independents
# 118029    Wanted to send a         quick follow up on if the
#
#                               2       source  \
# 3                   white cross  tempslibres
# 4             i think of lilacs  tempslibres
# 5                     breakfast  tempslibres
# 6              near the mailbox  tempslibres
# 7               in the shallows  tempslibres
# ...                         ...          ...
# 118025    what you said neither       twaiku
# 118026   inclined to think both       twaiku
# 118027         like Theresa May       twaiku
# 118028           into Democrats       twaiku
# 118029  blood is loud Talk soon       twaiku
#
#                                                      hash  unknown_word_count  \
# 3                     MEMORIALDAYASHADOWFOREACHWHITECROSS                   0
# 4               SPRINGRAINASTHEDOCTORSPEAKSITHINKOFLILACS                   0
# 5                      SPRINGMOONSETARICEBALLFORBREAKFAST                   1
# 6             SUNNYAFTERNOONANOLDMANLINGERSNEARTHEMAILBOX                   0
# 7                      CINCODEMAYOHORSESROLLINTHESHALLOWS                   1
# ...                                                   ...                 ...
# 118025  IMNOTASKINGDIDYOUSAYITNORCLARIFYWHATYOUSAIDNEI...                   0
# 118026      YOUARETRULYAMORONORALIARIMINCLINEDTOTHINKBOTH                   0
# 118027  AINTNOSELFIEONTHISEARTHTHATSGONNAMAKEMELIKETHE...                   0
# 118028   ISDOINGAGREATJOBTURNINGINDEPENDENTSINTODEMOCRATS                   0
# 118029  WANTEDTOSENDAQUICKFOLLOWUPONIFTHEBLOODISLOUDTA...                   0
#
#        0_syllables 1_syllables 2_syllables
# 3                5           5           2
# 4              2,3           5           5
# 5              3,4           4           2
# 6                5           5           4
# 7                5           3           4
# ...            ...         ...         ...
# 118025           5           7           5
# 118026           5           7           5
# 118027           5           7           5
# 118028           5           7           5
# 118029           5           7           5
#
# [143137 rows x 9 columns]

# %% [markdown]
# # Save to CSV

# %%
all_haikus.drop(columns=['unknown_word_count', 'hash']).to_csv(str(poem_path / 'haikus.csv'), index=False)
